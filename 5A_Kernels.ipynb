# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def N(x, mu = 0, s = 1):
  z = (x - mu)/s
  z **=2
  return np.exp(-z/2)

# %%
arr = [-10, -8, -6, -1, 0, 1, 6, 8, 10]

arr = list(map(N, arr))

print(arr)

plt.plot(arr)
# Out:
# [1.9287498479639178e-22, 1.2664165549094176e-14, 1.522997974471263e-08, 0.6065306597126334, 1.0, 0.6065306597126334, 1.522997974471263e-08, 1.2664165549094176e-14, 1.9287498479639178e-22]
